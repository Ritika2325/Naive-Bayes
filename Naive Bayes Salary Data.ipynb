# %%
import pandas as pd
import numpy as np

# %%
salary_test=pd.read_csv("C:/SalaryData_Test.csv")
salary_train=pd.read_csv("C:/SalaryData_Train.csv")

# %%
salary_test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            50   United-States   <=50K
# 2            0            40   United-States    >50K
# 3            0            40   United-States    >50K
# 4            0            30   United-States   <=50K

# %%
salary_train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            13   United-States   <=50K
# 2            0            40   United-States   <=50K
# 3            0            40   United-States   <=50K
# 4            0            40            Cuba   <=50K

# %%
salary_test.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
salary_train.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
salary_test.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
salary_train.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
salary_test1 = salary_test.drop('educationno',axis=1)
salary_test1.columns
# Out:
# Index(['age', 'workclass', 'education', 'maritalstatus', 'occupation',
#        'relationship', 'race', 'sex', 'capitalgain', 'capitalloss',
#        'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
salary_train1 = salary_train.drop('educationno',axis=1)
salary_train1.columns
# Out:
# Index(['age', 'workclass', 'education', 'maritalstatus', 'occupation',
#        'relationship', 'race', 'sex', 'capitalgain', 'capitalloss',
#        'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
str_col=['workclass','education','maritalstatus','occupation','relationship','race','sex','native']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder=LabelEncoder()

# %%
for i in str_col:
    salary_train1[i]=labelencoder.fit_transform(salary_train1[i])

# %%
salary_train1
# Out:
#        age  workclass  education  maritalstatus  occupation  relationship  \
# 0       39          5          9              4           0             1
# 1       50          4          9              2           3             0
# 2       38          2         11              0           5             1
# 3       53          2          1              2           5             0
# 4       28          2          9              2           9             5
# ...    ...        ...        ...            ...         ...           ...
# 30156   27          2          7              2          12             5
# 30157   40          2         11              2           6             0
# 30158   58          2         11              6           0             4
# 30159   22          2         11              4           0             3
# 30160   52          3         11              2           3             5
#
#        race  sex  capitalgain  capitalloss  hoursperweek  native  Salary
# 0         4    1         2174            0            40      37   <=50K
# 1         4    1            0            0            13      37   <=50K
# 2         4    1            0            0            40      37   <=50K
# 3         2    1            0            0            40      37   <=50K
# 4         2    0            0            0            40       4   <=50K
# ...     ...  ...          ...          ...           ...     ...     ...
# 30156     4    0            0            0            38      37   <=50K
# 30157     4    1            0            0            40      37    >50K
# 30158     4    0            0            0            40      37   <=50K
# 30159     4    1            0            0            20      37   <=50K
# 30160     4    0        15024            0            40      37    >50K
#
# [30161 rows x 13 columns]

# %%
salary_train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  int32
#  2   education      30161 non-null  int32
#  3   maritalstatus  30161 non-null  int32
#  4   occupation     30161 non-null  int32
#  5   relationship   30161 non-null  int32
#  6   race           30161 non-null  int32
#  7   sex            30161 non-null  int32
#  8   capitalgain    30161 non-null  int64
#  9   capitalloss    30161 non-null  int64
#  10  hoursperweek   30161 non-null  int64
#  11  native         30161 non-null  int32
#  12  Salary         30161 non-null  object
# dtypes: int32(8), int64(4), object(1)
# memory usage: 2.1+ MB

# %%
for i in str_col:
    salary_test[i] = labelencoder.fit_transform(salary_test[i])

# %%
salary_test
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# 0                 3     2    1            0            0            40
# 1                 0     4    1            0            0            50
# 2                 0     4    1            0            0            40
# 3                 0     2    1         7688            0            40
# 4                 1     4    1            0            0            30
# ...             ...   ...  ...          ...          ...           ...
# 15055             3     4    1            0            0            40
# 15056             1     4    0            0            0            36
# 15057             0     4    1            0            0            50
# 15058             3     1    1         5455            0            40
# 15059             0     4    1            0            0            60
#
#        native  Salary
# 0          37   <=50K
# 1          37   <=50K
# 2          37    >50K
# 3          37    >50K
# 4          37   <=50K
# ...       ...     ...
# 15055      37   <=50K
# 15056      37   <=50K
# 15057      37   <=50K
# 15058      37   <=50K
# 15059      37    >50K
#
# [15060 rows x 14 columns]

# %%
salary_test1=salary_test.drop('educationno',axis=1)

# %%
salary_test1
# Out:
#        age  workclass  education  maritalstatus  occupation  relationship  \
# 0       25          2          1              4           6             3
# 1       38          2         11              2           4             0
# 2       28          1          7              2          10             0
# 3       44          2         15              2           6             0
# 4       34          2          0              4           7             1
# ...    ...        ...        ...            ...         ...           ...
# 15055   33          2          9              4           9             3
# 15056   39          2          9              0           9             1
# 15057   38          2          9              2           9             0
# 15058   44          2          9              0           0             3
# 15059   35          3          9              2           3             0
#
#        race  sex  capitalgain  capitalloss  hoursperweek  native  Salary
# 0         2    1            0            0            40      37   <=50K
# 1         4    1            0            0            50      37   <=50K
# 2         4    1            0            0            40      37    >50K
# 3         2    1         7688            0            40      37    >50K
# 4         4    1            0            0            30      37   <=50K
# ...     ...  ...          ...          ...           ...     ...     ...
# 15055     4    1            0            0            40      37   <=50K
# 15056     4    0            0            0            36      37   <=50K
# 15057     4    1            0            0            50      37   <=50K
# 15058     1    1         5455            0            40      37   <=50K
# 15059     4    1            0            0            60      37    >50K
#
# [15060 rows x 13 columns]

# %%
salary_test1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  int32
#  2   education      15060 non-null  int32
#  3   maritalstatus  15060 non-null  int32
#  4   occupation     15060 non-null  int32
#  5   relationship   15060 non-null  int32
#  6   race           15060 non-null  int32
#  7   sex            15060 non-null  int32
#  8   capitalgain    15060 non-null  int64
#  9   capitalloss    15060 non-null  int64
#  10  hoursperweek   15060 non-null  int64
#  11  native         15060 non-null  int32
#  12  Salary         15060 non-null  object
# dtypes: int32(8), int64(4), object(1)
# memory usage: 1.0+ MB

# %%
salary_train1.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
salary_test1.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
Xtrain=salary_train1.iloc[:,0:12]
Xtrain
# Out:
#        age  workclass  education  maritalstatus  occupation  relationship  \
# 0       39          5          9              4           0             1
# 1       50          4          9              2           3             0
# 2       38          2         11              0           5             1
# 3       53          2          1              2           5             0
# 4       28          2          9              2           9             5
# ...    ...        ...        ...            ...         ...           ...
# 30156   27          2          7              2          12             5
# 30157   40          2         11              2           6             0
# 30158   58          2         11              6           0             4
# 30159   22          2         11              4           0             3
# 30160   52          3         11              2           3             5
#
#        race  sex  capitalgain  capitalloss  hoursperweek  native
# 0         4    1         2174            0            40      37
# 1         4    1            0            0            13      37
# 2         4    1            0            0            40      37
# 3         2    1            0            0            40      37
# 4         2    0            0            0            40       4
# ...     ...  ...          ...          ...           ...     ...
# 30156     4    0            0            0            38      37
# 30157     4    1            0            0            40      37
# 30158     4    0            0            0            40      37
# 30159     4    1            0            0            20      37
# 30160     4    0        15024            0            40      37
#
# [30161 rows x 12 columns]

# %%
Ytrain=salary_train1.iloc[:,12]
Ytrain
# Out:
# 0         <=50K
# 1         <=50K
# 2         <=50K
# 3         <=50K
# 4         <=50K
#           ...
# 30156     <=50K
# 30157      >50K
# 30158     <=50K
# 30159     <=50K
# 30160      >50K
# Name: Salary, Length: 30161, dtype: object

# %%
Xtest=salary_test1.iloc[:,0:12]
Xtest
# Out:
#        age  workclass  education  maritalstatus  occupation  relationship  \
# 0       25          2          1              4           6             3
# 1       38          2         11              2           4             0
# 2       28          1          7              2          10             0
# 3       44          2         15              2           6             0
# 4       34          2          0              4           7             1
# ...    ...        ...        ...            ...         ...           ...
# 15055   33          2          9              4           9             3
# 15056   39          2          9              0           9             1
# 15057   38          2          9              2           9             0
# 15058   44          2          9              0           0             3
# 15059   35          3          9              2           3             0
#
#        race  sex  capitalgain  capitalloss  hoursperweek  native
# 0         2    1            0            0            40      37
# 1         4    1            0            0            50      37
# 2         4    1            0            0            40      37
# 3         2    1         7688            0            40      37
# 4         4    1            0            0            30      37
# ...     ...  ...          ...          ...           ...     ...
# 15055     4    1            0            0            40      37
# 15056     4    0            0            0            36      37
# 15057     4    1            0            0            50      37
# 15058     1    1         5455            0            40      37
# 15059     4    1            0            0            60      37
#
# [15060 rows x 12 columns]

# %%
Ytest=salary_test1.iloc[:,12]
Ytest
# Out:
# 0         <=50K
# 1         <=50K
# 2          >50K
# 3          >50K
# 4         <=50K
#           ...
# 15055     <=50K
# 15056     <=50K
# 15057     <=50K
# 15058     <=50K
# 15059      >50K
# Name: Salary, Length: 15060, dtype: object

# %%
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
# feature extraction
bestfeatures = SelectKBest(score_func=chi2,k=8)
fit = bestfeatures.fit(Xtrain,Ytrain)

# %%
dfscores=pd.DataFrame(fit.scores_)
dfscores
# Out:
#                0
# 0   7.927146e+03
# 1   4.061261e+00
# 2   2.648158e+02
# 3   9.822277e+02
# 4   2.185974e+02
# 5   3.435383e+03
# 6   2.933954e+01
# 7   4.592193e+02
# 8   7.412466e+07
# 9   1.258786e+06
# 10  5.569194e+03
# 11  1.670732e+01

# %%
dfcolumns = pd.DataFrame(Xtrain.columns)
dfcolumns
# Out:
#                 0
# 0             age
# 1       workclass
# 2       education
# 3   maritalstatus
# 4      occupation
# 5    relationship
# 6            race
# 7             sex
# 8     capitalgain
# 9     capitalloss
# 10   hoursperweek
# 11         native

# %%
featureScores=pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']
featureScores
# Out:
#             Specs         Score
# 0             age  7.927146e+03
# 1       workclass  4.061261e+00
# 2       education  2.648158e+02
# 3   maritalstatus  9.822277e+02
# 4      occupation  2.185974e+02
# 5    relationship  3.435383e+03
# 6            race  2.933954e+01
# 7             sex  4.592193e+02
# 8     capitalgain  7.412466e+07
# 9     capitalloss  1.258786e+06
# 10   hoursperweek  5.569194e+03
# 11         native  1.670732e+01

# %%
print(featureScores.nlargest(8,'Score'))
# Out:
#             Specs         Score
# 8     capitalgain  7.412466e+07
# 9     capitalloss  1.258786e+06
# 0             age  7.927146e+03
# 10   hoursperweek  5.569194e+03
# 5    relationship  3.435383e+03
# 3   maritalstatus  9.822277e+02
# 7             sex  4.592193e+02
# 2       education  2.648158e+02

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(Xtrain, Ytrain)
print(model.feature_importances_)
feat_importances = pd.Series(model.feature_importances_, index=Xtrain.columns)
feat_importances.nlargest(8).plot(kind='barh')
plt.show()
# Out:
# [0.21878025 0.05004662 0.11062948 0.08140884 0.10289538 0.09655513
#  0.01662774 0.03212752 0.10971899 0.03708934 0.12463298 0.01948773]

# %%
import seaborn as sns

# %%
corrmat = salary_train1.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(12,12))
#plot heat map
g=sns.heatmap(salary_train1[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
Xtrain1=salary_train1.drop('workclass',axis=1)
Xtrain1
# Out:
#        age  education  maritalstatus  occupation  relationship  race  sex  \
# 0       39          9              4           0             1     4    1
# 1       50          9              2           3             0     4    1
# 2       38         11              0           5             1     4    1
# 3       53          1              2           5             0     2    1
# 4       28          9              2           9             5     2    0
# ...    ...        ...            ...         ...           ...   ...  ...
# 30156   27          7              2          12             5     4    0
# 30157   40         11              2           6             0     4    1
# 30158   58         11              6           0             4     4    0
# 30159   22         11              4           0             3     4    1
# 30160   52         11              2           3             5     4    0
#
#        capitalgain  capitalloss  hoursperweek  native  Salary
# 0             2174            0            40      37   <=50K
# 1                0            0            13      37   <=50K
# 2                0            0            40      37   <=50K
# 3                0            0            40      37   <=50K
# 4                0            0            40       4   <=50K
# ...            ...          ...           ...     ...     ...
# 30156            0            0            38      37   <=50K
# 30157            0            0            40      37    >50K
# 30158            0            0            40      37   <=50K
# 30159            0            0            20      37   <=50K
# 30160        15024            0            40      37    >50K
#
# [30161 rows x 12 columns]

# %%
Xtrain1=Xtrain1.drop('race',axis=1)
Xtrain1
# Out:
#        age  education  maritalstatus  occupation  relationship  sex  \
# 0       39          9              4           0             1    1
# 1       50          9              2           3             0    1
# 2       38         11              0           5             1    1
# 3       53          1              2           5             0    1
# 4       28          9              2           9             5    0
# ...    ...        ...            ...         ...           ...  ...
# 30156   27          7              2          12             5    0
# 30157   40         11              2           6             0    1
# 30158   58         11              6           0             4    0
# 30159   22         11              4           0             3    1
# 30160   52         11              2           3             5    0
#
#        capitalgain  capitalloss  hoursperweek  native  Salary
# 0             2174            0            40      37   <=50K
# 1                0            0            13      37   <=50K
# 2                0            0            40      37   <=50K
# 3                0            0            40      37   <=50K
# 4                0            0            40       4   <=50K
# ...            ...          ...           ...     ...     ...
# 30156            0            0            38      37   <=50K
# 30157            0            0            40      37    >50K
# 30158            0            0            40      37   <=50K
# 30159            0            0            20      37   <=50K
# 30160        15024            0            40      37    >50K
#
# [30161 rows x 11 columns]

# %%
Xtrain1=Xtrain1.drop('native',axis=1)
Xtrain1
# Out:
#        age  education  maritalstatus  occupation  relationship  sex  \
# 0       39          9              4           0             1    1
# 1       50          9              2           3             0    1
# 2       38         11              0           5             1    1
# 3       53          1              2           5             0    1
# 4       28          9              2           9             5    0
# ...    ...        ...            ...         ...           ...  ...
# 30156   27          7              2          12             5    0
# 30157   40         11              2           6             0    1
# 30158   58         11              6           0             4    0
# 30159   22         11              4           0             3    1
# 30160   52         11              2           3             5    0
#
#        capitalgain  capitalloss  hoursperweek  Salary
# 0             2174            0            40   <=50K
# 1                0            0            13   <=50K
# 2                0            0            40   <=50K
# 3                0            0            40   <=50K
# 4                0            0            40   <=50K
# ...            ...          ...           ...     ...
# 30156            0            0            38   <=50K
# 30157            0            0            40    >50K
# 30158            0            0            40   <=50K
# 30159            0            0            20   <=50K
# 30160        15024            0            40    >50K
#
# [30161 rows x 10 columns]

# %%
Xtrain1=Xtrain1.drop('occupation',axis=1)
Xtrain1
# Out:
#        age  education  maritalstatus  relationship  sex  capitalgain  \
# 0       39          9              4             1    1         2174
# 1       50          9              2             0    1            0
# 2       38         11              0             1    1            0
# 3       53          1              2             0    1            0
# 4       28          9              2             5    0            0
# ...    ...        ...            ...           ...  ...          ...
# 30156   27          7              2             5    0            0
# 30157   40         11              2             0    1            0
# 30158   58         11              6             4    0            0
# 30159   22         11              4             3    1            0
# 30160   52         11              2             5    0        15024
#
#        capitalloss  hoursperweek  Salary
# 0                0            40   <=50K
# 1                0            13   <=50K
# 2                0            40   <=50K
# 3                0            40   <=50K
# 4                0            40   <=50K
# ...            ...           ...     ...
# 30156            0            38   <=50K
# 30157            0            40    >50K
# 30158            0            40   <=50K
# 30159            0            20   <=50K
# 30160            0            40    >50K
#
# [30161 rows x 9 columns]

# %%
X_sal=Xtrain1.iloc[:,0:8]
Y_sal=Xtrain1.iloc[:,8]

# %%
X_sal
# Out:
#        age  education  maritalstatus  relationship  sex  capitalgain  \
# 0       39          9              4             1    1         2174
# 1       50          9              2             0    1            0
# 2       38         11              0             1    1            0
# 3       53          1              2             0    1            0
# 4       28          9              2             5    0            0
# ...    ...        ...            ...           ...  ...          ...
# 30156   27          7              2             5    0            0
# 30157   40         11              2             0    1            0
# 30158   58         11              6             4    0            0
# 30159   22         11              4             3    1            0
# 30160   52         11              2             5    0        15024
#
#        capitalloss  hoursperweek
# 0                0            40
# 1                0            13
# 2                0            40
# 3                0            40
# 4                0            40
# ...            ...           ...
# 30156            0            38
# 30157            0            40
# 30158            0            40
# 30159            0            20
# 30160            0            40
#
# [30161 rows x 8 columns]

# %%
Y_sal
# Out:
# 0         <=50K
# 1         <=50K
# 2         <=50K
# 3         <=50K
# 4         <=50K
#           ...
# 30156     <=50K
# 30157      >50K
# 30158     <=50K
# 30159     <=50K
# 30160      >50K
# Name: Salary, Length: 30161, dtype: object

# %%
Xtest1=salary_test1.drop('workclass',axis=1)
Xtest1
# Out:
#        age  education  maritalstatus  occupation  relationship  race  sex  \
# 0       25          1              4           6             3     2    1
# 1       38         11              2           4             0     4    1
# 2       28          7              2          10             0     4    1
# 3       44         15              2           6             0     2    1
# 4       34          0              4           7             1     4    1
# ...    ...        ...            ...         ...           ...   ...  ...
# 15055   33          9              4           9             3     4    1
# 15056   39          9              0           9             1     4    0
# 15057   38          9              2           9             0     4    1
# 15058   44          9              0           0             3     1    1
# 15059   35          9              2           3             0     4    1
#
#        capitalgain  capitalloss  hoursperweek  native  Salary
# 0                0            0            40      37   <=50K
# 1                0            0            50      37   <=50K
# 2                0            0            40      37    >50K
# 3             7688            0            40      37    >50K
# 4                0            0            30      37   <=50K
# ...            ...          ...           ...     ...     ...
# 15055            0            0            40      37   <=50K
# 15056            0            0            36      37   <=50K
# 15057            0            0            50      37   <=50K
# 15058         5455            0            40      37   <=50K
# 15059            0            0            60      37    >50K
#
# [15060 rows x 12 columns]

# %%
Xtest1=Xtest1.drop('occupation',axis=1)
Xtest1
# Out:
#        age  education  maritalstatus  relationship  race  sex  capitalgain  \
# 0       25          1              4             3     2    1            0
# 1       38         11              2             0     4    1            0
# 2       28          7              2             0     4    1            0
# 3       44         15              2             0     2    1         7688
# 4       34          0              4             1     4    1            0
# ...    ...        ...            ...           ...   ...  ...          ...
# 15055   33          9              4             3     4    1            0
# 15056   39          9              0             1     4    0            0
# 15057   38          9              2             0     4    1            0
# 15058   44          9              0             3     1    1         5455
# 15059   35          9              2             0     4    1            0
#
#        capitalloss  hoursperweek  native  Salary
# 0                0            40      37   <=50K
# 1                0            50      37   <=50K
# 2                0            40      37    >50K
# 3                0            40      37    >50K
# 4                0            30      37   <=50K
# ...            ...           ...     ...     ...
# 15055            0            40      37   <=50K
# 15056            0            36      37   <=50K
# 15057            0            50      37   <=50K
# 15058            0            40      37   <=50K
# 15059            0            60      37    >50K
#
# [15060 rows x 11 columns]

# %%
Xtest1=Xtest1.drop('race',axis=1)
Xtest1
# Out:
#        age  education  maritalstatus  relationship  sex  capitalgain  \
# 0       25          1              4             3    1            0
# 1       38         11              2             0    1            0
# 2       28          7              2             0    1            0
# 3       44         15              2             0    1         7688
# 4       34          0              4             1    1            0
# ...    ...        ...            ...           ...  ...          ...
# 15055   33          9              4             3    1            0
# 15056   39          9              0             1    0            0
# 15057   38          9              2             0    1            0
# 15058   44          9              0             3    1         5455
# 15059   35          9              2             0    1            0
#
#        capitalloss  hoursperweek  native  Salary
# 0                0            40      37   <=50K
# 1                0            50      37   <=50K
# 2                0            40      37    >50K
# 3                0            40      37    >50K
# 4                0            30      37   <=50K
# ...            ...           ...     ...     ...
# 15055            0            40      37   <=50K
# 15056            0            36      37   <=50K
# 15057            0            50      37   <=50K
# 15058            0            40      37   <=50K
# 15059            0            60      37    >50K
#
# [15060 rows x 10 columns]

# %%
Xtest1=Xtest1.drop('native',axis=1)
Xtest1
# Out:
#        age  education  maritalstatus  relationship  sex  capitalgain  \
# 0       25          1              4             3    1            0
# 1       38         11              2             0    1            0
# 2       28          7              2             0    1            0
# 3       44         15              2             0    1         7688
# 4       34          0              4             1    1            0
# ...    ...        ...            ...           ...  ...          ...
# 15055   33          9              4             3    1            0
# 15056   39          9              0             1    0            0
# 15057   38          9              2             0    1            0
# 15058   44          9              0             3    1         5455
# 15059   35          9              2             0    1            0
#
#        capitalloss  hoursperweek  Salary
# 0                0            40   <=50K
# 1                0            50   <=50K
# 2                0            40    >50K
# 3                0            40    >50K
# 4                0            30   <=50K
# ...            ...           ...     ...
# 15055            0            40   <=50K
# 15056            0            36   <=50K
# 15057            0            50   <=50K
# 15058            0            40   <=50K
# 15059            0            60    >50K
#
# [15060 rows x 9 columns]

# %%
Xtest1=Xtest1.drop('Salary',axis=1)
Xtest1
# Out:
#        age  education  maritalstatus  relationship  sex  capitalgain  \
# 0       25          1              4             3    1            0
# 1       38         11              2             0    1            0
# 2       28          7              2             0    1            0
# 3       44         15              2             0    1         7688
# 4       34          0              4             1    1            0
# ...    ...        ...            ...           ...  ...          ...
# 15055   33          9              4             3    1            0
# 15056   39          9              0             1    0            0
# 15057   38          9              2             0    1            0
# 15058   44          9              0             3    1         5455
# 15059   35          9              2             0    1            0
#
#        capitalloss  hoursperweek
# 0                0            40
# 1                0            50
# 2                0            40
# 3                0            40
# 4                0            30
# ...            ...           ...
# 15055            0            40
# 15056            0            36
# 15057            0            50
# 15058            0            40
# 15059            0            60
#
# [15060 rows x 8 columns]

# %%
from sklearn.naive_bayes import MultinomialNB as MB
from sklearn.naive_bayes import GaussianNB as GB

# %%
salary_MB = MB()
salary_MB.fit(X_sal,Y_sal)
# Out:
# MultinomialNB()

# %%
train_pred_m = salary_MB.predict(X_sal)

# %%
accuracy_train_m = np.mean(train_pred_m==Y_sal)

# %%
accuracy_train_m
# Out:
# 0.7729186698053778

# %%
y_pred = salary_MB.predict(Xtest1)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
acc = accuracy_score(Ytest, y_pred) * 100
print("Accuracy =", acc)
# Out:
# Accuracy = 77.49667994687915

# %%
#GaussianNB
salary_GB = GB()
salary_GB.fit(X_sal,Y_sal)
# Out:
# GaussianNB()

# %%
y_pred = salary_GB.predict(Xtest1)

# %%
acc = accuracy_score(Ytest, y_pred) * 100
print("Accuracy =", acc)
# Out:
# Accuracy = 79.13014608233732

# %%
#Tunning using GridSearchCV

# %%
from sklearn.naive_bayes import GaussianNB as GB
from sklearn.model_selection import GridSearchCV

# %%
param_grid_nb = {
    'var_smoothing': np.logspace(0,-9, num=100)
}

# %%
nbModel_grid = GridSearchCV(estimator=GB(), param_grid=param_grid_nb, verbose=1, cv=10, n_jobs=-1)

# %%
nbModel_grid.fit(X_sal,Y_sal)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:   42.3s
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed:   50.4s finished
# GridSearchCV(cv=10, estimator=GaussianNB(), n_jobs=-1,
#              param_grid={'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#        4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#        1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#        8.11130831e-02, 6.57933225e-02, 5.33669923e-02, 4.32876128e-02,
#        3.51119173e-02, 2.848035...
#        1.23284674e-07, 1.00000000e-07, 8.11130831e-08, 6.57933225e-08,
#        5.33669923e-08, 4.32876128e-08, 3.51119173e-08, 2.84803587e-08,
#        2.31012970e-08, 1.87381742e-08, 1.51991108e-08, 1.23284674e-08,
#        1.00000000e-08, 8.11130831e-09, 6.57933225e-09, 5.33669923e-09,
#        4.32876128e-09, 3.51119173e-09, 2.84803587e-09, 2.31012970e-09,
#        1.87381742e-09, 1.51991108e-09, 1.23284674e-09, 1.00000000e-09])},
#              verbose=1)

# %%
print(nbModel_grid.best_estimator_)
# Out:
# GaussianNB(var_smoothing=0.0023101297000831605)

# %%
y_pred = nbModel_grid.predict(Xtest1)
print(y_pred)
# Out:
# [' <=50K' ' <=50K' ' <=50K' ... ' <=50K' ' >50K' ' <=50K']

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
acc = accuracy_score(Ytest, y_pred) * 100
print("Accuracy =", acc)
# Out:
# Accuracy = 80.0531208499336
